# %%
import numpy as np
import math
import matplotlib.pyplot as plt

p = np.random.random(2)
print(p)
a = p[0]*100
b = p[1]*50

plt.xlim(0, 100)
plt.ylim(0, 50)


plt.plot(a,b,'ro')
plt.xlabel("distance (m)")
plt.ylabel("height (m)")
# Out:
# [0.79657937 0.93392658]
# Text(0, 0.5, 'height (m)')

# %%
v = float(input("enter the initial velocity:"))
theta = math.radians(float(input("enter the initial angle:")))

t = np.linspace(0,20,100)
x = v * math.cos(theta) * t
y = v * math.sin(theta) * t - 0.5 * 9.8 * t**2

plt.plot(a,b,'ro')
plt.plot(x,y)

plt.xlim(0, 100)
plt.ylim(0, 50)
plt.xlabel("distance (m)")
plt.ylabel("height (m)")
# Out:
# enter the initial velocity:30
# enter the initial angle:60
# Text(0, 0.5, 'height (m)')
