# %%
# %matplotlib inline
import matplotlib.image as mpimg

im = mpimg.imread('P1120107.JPG')

# %%
import matplotlib.pyplot as plt
plt.imshow(im)

# %%
print(im.shape)
# Out:
# (3672, 4896, 3)

# %%
r_im = im[:, :, 0]
plt.imshow(r_im)

# %%
g_im = im[:, :, 1]
plt.imshow(g_im)

# %%
b_im = im[:, :, 2]
plt.imshow(b_im)

# %%
plt.hist(b_im.ravel())
# Out:
# (array([ 118493.,  239671.,  261542.,  202779.,  159160.,  122206.,
#          128572., 4362245., 9295533., 3087911.]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(g_im.ravel())
# Out:
# (array([1.548780e+05, 2.497890e+05, 2.549760e+05, 2.149080e+05,
#         2.952921e+06, 9.343253e+06, 4.394723e+06, 3.930090e+05,
#         1.187900e+04, 7.776000e+03]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <a list of 10 Patch objects>)

# %%
gb_im = g_im + b_im
plt.hist(gb_im.ravel())
# Out:
# (array([  96724.,  201282., 3918723., 4640091., 5021657., 2445269.,
#         1246046.,  219978.,   97717.,   90625.]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <a list of 10 Patch objects>)

# %%
import numpy as np
print(np.mean(b_im))
print(np.median(b_im))
# Out:
# 206.0231294587552
# 213.0
